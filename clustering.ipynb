# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, AgglomerativeClustering, MeanShift
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.pipeline import Pipeline
import numpy as np

# %%
df = pd.read_csv('/content/jewelleryDataSet.csv')
df.head()
# Out:
#    Unnamed: 0  Age  Income  SpendingScore       Savings
# 0           0   58   77769       0.791329   6559.829923
# 1           1   59   81799       0.791082   5417.661426
# 2           2   62   74751       0.702657   9258.992965
# 3           3   59   74373       0.765680   7346.334504
# 4           4   87   17760       0.348778  16869.507130

# %%
X=df.values

# %%
X
# Out:
# array([[0.00000000e+00, 5.80000000e+01, 7.77690000e+04, 7.91328777e-01,
#         6.55982992e+03],
#        [1.00000000e+00, 5.90000000e+01, 8.17990000e+04, 7.91082047e-01,
#         5.41766143e+03],
#        [2.00000000e+00, 6.20000000e+01, 7.47510000e+04, 7.02656952e-01,
#         9.25899297e+03],
#        ...,
#        [5.02000000e+02, 9.00000000e+01, 3.52970000e+04, 3.55149019e-01,
#         1.60914020e+04],
#        [5.03000000e+02, 9.10000000e+01, 2.06810000e+04, 3.54679169e-01,
#         1.84010884e+04],
#        [5.04000000e+02, 8.90000000e+01, 3.02670000e+04, 2.89310066e-01,
#         1.43863519e+04]])

# %%
#columns=['Gender','family_history_with_overweight','CAEC','SMOKE','CALC','MTRANS','NObeyesdad']

# %%
#from sklearn.preprocessing import LabelEncoder
#le = LabelEncoder()
#for col in columns:
  #df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    Unnamed: 0  Age  Income  SpendingScore       Savings
# 0           0   58   77769       0.791329   6559.829923
# 1           1   59   81799       0.791082   5417.661426
# 2           2   62   74751       0.702657   9258.992965
# 3           3   59   74373       0.765680   7346.334504
# 4           4   87   17760       0.348778  16869.507130

# %%
def compute_metrics(X, labels):
    n_clusters = len(set(labels))


    if n_clusters > 1:
        silhouette = silhouette_score(X, labels)
        calinski_harabasz = calinski_harabasz_score(X, labels)
        davies_bouldin = davies_bouldin_score(X, labels)
    else:
        silhouette = np.nan
        calinski_harabasz = np.nan
        davies_bouldin = np.nan

    return {
        "Silhouette": silhouette,
        "Calinski-Harabasz": calinski_harabasz,
        "Davies-Bouldin": davies_bouldin
    }

# %%
def get_preprocessing_pipeline(with_normalization=False, with_pca=False, with_transform=False):
    steps = []

    if with_normalization:
        steps.append(('scaler', StandardScaler()))

    if with_transform:
        steps.append(('custom_transform', StandardScaler()))

    if with_pca:
        steps.append(('pca', PCA(n_components=2)))

    return Pipeline(steps) if steps else None

# %%
clustering_methods = {
    "KMeans": KMeans,
    "Hierarchical": AgglomerativeClustering,
    "MeanShift": MeanShift
}

# %%
preprocessing_scenarios = {
    "No Data Processing": (False, False, False),
    "Using Normalization": (True, False, False),
    "Using Transform": (False, False, True),
    "Using PCA": (False, True, False),
    "Using T+N": (True, False, True),
    "T+N+PCA": (True, True, True)
}

# %%
cluster_values = [3, 4, 5]

# %%
results = []

# %%
for clustering_method_name, clustering_method in clustering_methods.items():
    for scenario_name, (with_normalization, with_pca, with_transform) in preprocessing_scenarios.items():

        preprocessing_pipeline = get_preprocessing_pipeline(with_normalization, with_pca, with_transform)


        if preprocessing_pipeline:
            X_transformed = preprocessing_pipeline.fit_transform(X)
        else:
            X_transformed = X


        if clustering_method_name == "MeanShift":
            cluster_model = clustering_method()
            labels = cluster_model.fit_predict(X_transformed)


            metrics = compute_metrics(X_transformed, labels)
            metrics["Parameters"] = clustering_method_name
            metrics["Scenario"] = scenario_name
            metrics["Clusters (c)"] = "Auto"


            results.append(metrics)

        else:

            for c in cluster_values:
                cluster_model = clustering_method(n_clusters=c)
                labels = cluster_model.fit_predict(X_transformed)


                metrics = compute_metrics(X_transformed, labels)
                metrics["Parameters"] = clustering_method_name
                metrics["Scenario"] = scenario_name
                metrics["Clusters (c)"] = c


                results.append(metrics)

# %%
df_results = pd.DataFrame(results)

# %%
df_results
# Out:
#     Silhouette  Calinski-Harabasz  Davies-Bouldin    Parameters  \
# 0     0.739201        3566.668168        0.343671        KMeans
# 1     0.721496        5007.199788        0.408418        KMeans
# 2     0.681269        4628.907459        0.470079        KMeans
# 3     0.508922         464.629880        0.860450        KMeans
# 4     0.512855         387.520712        0.783037        KMeans
# 5     0.426912         386.273544        0.929068        KMeans
# 6     0.508922         464.629880        0.860450        KMeans
# 7     0.522598         443.796901        0.813131        KMeans
# 8     0.490830         419.927040        0.806659        KMeans
# 9     0.739317        3567.544408        0.343527        KMeans
# 10    0.721672        5009.700302        0.408197        KMeans
# 11    0.619992        4569.237387        0.554799        KMeans
# 12    0.508922         464.629880        0.860450        KMeans
# 13    0.456871         411.152665        0.978878        KMeans
# 14    0.427631         385.586143        0.937722        KMeans
# 15    0.724546        1393.541195        0.446126        KMeans
# 16    0.695297        1099.978299        0.403614        KMeans
# 17    0.774878        4057.791565        0.334240        KMeans
# 18    0.738951        3541.768466        0.340889  Hierarchical
# 19    0.705788        4824.915572        0.434081  Hierarchical
# 20    0.690583        4513.752740        0.465332  Hierarchical
# 21    0.508922         464.629880        0.860450  Hierarchical
# 22    0.522598         443.796901        0.813131  Hierarchical
# 23    0.540210         433.448773        0.801759  Hierarchical
# 24    0.508922         464.629880        0.860450  Hierarchical
# 25    0.522598         443.796901        0.813131  Hierarchical
# 26    0.540210         433.448773        0.801759  Hierarchical
# 27    0.739068        3542.632702        0.340738  Hierarchical
# 28    0.705973        4827.239636        0.433862  Hierarchical
# 29    0.690839        4516.446431        0.464944  Hierarchical
# 30    0.508922         464.629880        0.860450  Hierarchical
# 31    0.522598         443.796901        0.813131  Hierarchical
# 32    0.540210         433.448773        0.801759  Hierarchical
# 33    0.724546        1393.541195        0.446126  Hierarchical
# 34    0.796918        3126.831875        0.280023  Hierarchical
# 35    0.774878        4057.791565        0.334240  Hierarchical
# 36    0.739201        3566.668168        0.343671     MeanShift
# 37         NaN                NaN             NaN     MeanShift
# 38         NaN                NaN             NaN     MeanShift
# 39    0.739317        3567.544408        0.343527     MeanShift
# 40         NaN                NaN             NaN     MeanShift
# 41    0.796918        3126.831875        0.280023     MeanShift
#
#                Scenario Clusters (c)
# 0    No Data Processing            3
# 1    No Data Processing            4
# 2    No Data Processing            5
# 3   Using Normalization            3
# 4   Using Normalization            4
# 5   Using Normalization            5
# 6       Using Transform            3
# 7       Using Transform            4
# 8       Using Transform            5
# 9             Using PCA            3
# 10            Using PCA            4
# 11            Using PCA            5
# 12            Using T+N            3
# 13            Using T+N            4
# 14            Using T+N            5
# 15              T+N+PCA            3
# 16              T+N+PCA            4
# 17              T+N+PCA            5
# 18   No Data Processing            3
# 19   No Data Processing            4
# 20   No Data Processing            5
# 21  Using Normalization            3
# 22  Using Normalization            4
# 23  Using Normalization            5
# 24      Using Transform            3
# 25      Using Transform            4
# 26      Using Transform            5
# 27            Using PCA            3
# 28            Using PCA            4
# 29            Using PCA            5
# 30            Using T+N            3
# 31            Using T+N            4
# 32            Using T+N            5
# 33              T+N+PCA            3
# 34              T+N+PCA            4
# 35              T+N+PCA            5
# 36   No Data Processing         Auto
# 37  Using Normalization         Auto
# 38      Using Transform         Auto
# 39            Using PCA         Auto
# 40            Using T+N         Auto
# 41              T+N+PCA         Auto

# %%
output_file = 'clustering_results.xlsx'
df_results.to_excel(output_file, index=False)
